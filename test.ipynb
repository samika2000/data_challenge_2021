# %%
import pandas as pd
import numpy as np
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
# %matplotlib inline 
sns.set(color_codes=True)

# %%
df = pd.read_csv("final_cleaned.csv")

# %%
df.count()
# Out:
# Item_Identifier              8322
# Item_Weight                  8322
# Item_Fat_Content             8322
# Item_Visibility              8322
# Item_Type                    8322
# Item_MRP                     8322
# Outlet_Identifier            8322
# Outlet_Establishment_Year    8322
# Outlet_Size                  8322
# Outlet_Location_Type         8322
# Outlet_Type                  8322
# Item_Outlet_Sales            8322
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# ## Cleaning up columns

# %% [markdown]
# #### Cleaning up the Item_Fat_Content column

# %%
l = len(df["Item_Fat_Content"])
for i in range(l):
    if df["Item_Fat_Content"][i] == "LF" or df["Item_Fat_Content"][i] == "low fat" or df["Item_Fat_Content"][i] == "Low Fat":
        df["Item_Fat_Content"][i] = df["Item_Fat_Content"][i].replace(df["Item_Fat_Content"][i], "L")
    elif df["Item_Fat_Content"][i] == "reg" or df["Item_Fat_Content"][i] == "Regular":
        df["Item_Fat_Content"][i] = df["Item_Fat_Content"][i].replace(df["Item_Fat_Content"][i], "R")
# Out:
# <ipython-input-106-333a97c919b5>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Item_Fat_Content"][i] = df["Item_Fat_Content"][i].replace(df["Item_Fat_Content"][i], "R")
# <ipython-input-106-333a97c919b5>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Item_Fat_Content"][i] = df["Item_Fat_Content"][i].replace(df["Item_Fat_Content"][i], "L")

# %%
df["Item_Fat_Content"].value_counts()
# Out:
# L    5395
# R    2927
# Name: Item_Fat_Content, dtype: int64

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDB14        20.25                R         0.171939
# 1           FDS52         8.89                L         0.009163
# 2           NCN07        18.50                L         0.056816
# 3           FDI32        17.70                L         0.291865
# 4           FDR47        17.85                L         0.070088
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                 Canned   92.5120            OUT010
# 1           Frozen Foods  101.7016            OUT010
# 2                 Others  132.1284            OUT010
# 3  Fruits and Vegetables  115.1834            OUT010
# 4                 Breads  196.5794            OUT010
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type    Outlet_Type  \
# 0                       1998       Small               Tier 3  Grocery Store
# 1                       1998       Small               Tier 3  Grocery Store
# 2                       1998       Small               Tier 3  Grocery Store
# 3                       1998       Small               Tier 3  Grocery Store
# 4                       1998       Small               Tier 3  Grocery Store
#
#    Item_Outlet_Sales
# 0           186.4240
# 1           101.2016
# 2           263.6568
# 3           345.5502
# 4           585.2382

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDB14       20.250                R         0.171939
# 1              FDS52        8.890                L         0.009163
# 2              NCN07       18.500                L         0.056816
# 3              FDI32       17.700                L         0.291865
# 4              FDR47       17.850                L         0.070088
# ...              ...          ...              ...              ...
# 8317           FDT57       15.200                L         0.018943
# 8318           FDW02        4.805                R         0.037517
# 8319           NCO02       11.150                L         0.073013
# 8320           FDJ15       11.350                R         0.023210
# 8321           FDL10        8.395                L         0.039301
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                    Canned   92.5120            OUT010
# 1              Frozen Foods  101.7016            OUT010
# 2                    Others  132.1284            OUT010
# 3     Fruits and Vegetables  115.1834            OUT010
# 4                    Breads  196.5794            OUT010
# ...                     ...       ...               ...
# 8317            Snack Foods  236.0248            OUT027
# 8318                  Dairy  124.3704            OUT027
# 8319                 Others   67.5142            OUT027
# 8320                  Dairy  183.3608            OUT027
# 8321            Snack Foods   99.5042            OUT027
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1998       Small               Tier 3
# 1                          1998       Small               Tier 3
# 2                          1998       Small               Tier 3
# 3                          1998       Small               Tier 3
# 4                          1998       Small               Tier 3
# ...                         ...         ...                  ...
# 8317                       1985      Medium               Tier 3
# 8318                       1985      Medium               Tier 3
# 8319                       1985      Medium               Tier 3
# 8320                       1985      Medium               Tier 3
# 8321                       1985      Medium               Tier 3
#
#             Outlet_Type  Item_Outlet_Sales
# 0         Grocery Store           186.4240
# 1         Grocery Store           101.2016
# 2         Grocery Store           263.6568
# 3         Grocery Store           345.5502
# 4         Grocery Store           585.2382
# ...                 ...                ...
# 8317  Supermarket Type3          6636.6944
# 8318  Supermarket Type3          3004.0896
# 8319  Supermarket Type3          2306.9970
# 8320  Supermarket Type3          6064.1064
# 8321  Supermarket Type3          1884.8798
#
# [8322 rows x 12 columns]

# %% [markdown]
# ### Normalizing stuff

# %%
df[['Item_Weight','Item_Visibility','Item_MRP','Outlet_Establishment_Year']]
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year
# 0          20.250         0.171939   92.5120                       1998
# 1           8.890         0.009163  101.7016                       1998
# 2          18.500         0.056816  132.1284                       1998
# 3          17.700         0.291865  115.1834                       1998
# 4          17.850         0.070088  196.5794                       1998
# ...           ...              ...       ...                        ...
# 8317       15.200         0.018943  236.0248                       1985
# 8318        4.805         0.037517  124.3704                       1985
# 8319       11.150         0.073013   67.5142                       1985
# 8320       11.350         0.023210  183.3608                       1985
# 8321        8.395         0.039301   99.5042                       1985
#
# [8322 rows x 4 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
min_max = MinMaxScaler(feature_range=(0, 1))

# %%
Item_MRP = min_max.fit_transform(np.array(df['Item_MRP']).reshape(-1,1)).flatten()
Item_MRP = pd.Series(Item_MRP)
Item_MRP
# Out:
# 0       0.259857
# 1       0.298863
# 2       0.428010
# 3       0.356086
# 4       0.701573
#           ...
# 8317    0.868999
# 8318    0.395081
# 8319    0.153754
# 8320    0.645466
# 8321    0.289536
# Length: 8322, dtype: float64

# %%
Item_Weight = min_max.fit_transform(np.array(df['Item_Weight']).reshape(-1,1)).flatten()
Item_Weight = pd.Series(Item_Weight)
Item_Weight
# Out:
# 0       0.934504
# 1       0.258113
# 2       0.830307
# 3       0.782673
# 4       0.791605
#           ...
# 8317    0.633820
# 8318    0.014885
# 8319    0.392676
# 8320    0.404585
# 8321    0.228639
# Length: 8322, dtype: float64

# %%
Outlet_Establishment_Year = min_max.fit_transform(np.array(df['Outlet_Establishment_Year']).reshape(-1,1)).flatten()
Outlet_Establishment_Year = pd.Series(Outlet_Establishment_Year)
Outlet_Establishment_Year
# Out:
# 0       0.541667
# 1       0.541667
# 2       0.541667
# 3       0.541667
# 4       0.541667
#           ...
# 8317    0.000000
# 8318    0.000000
# 8319    0.000000
# 8320    0.000000
# 8321    0.000000
# Length: 8322, dtype: float64

# %%
df['Item_MRP'] = Item_MRP
df['Item_Weight'] = Item_Weight
df['Outlet_Establishment_Year'] = Outlet_Establishment_Year

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDB14     0.934504                R         0.171939
# 1              FDS52     0.258113                L         0.009163
# 2              NCN07     0.830307                L         0.056816
# 3              FDI32     0.782673                L         0.291865
# 4              FDR47     0.791605                L         0.070088
# ...              ...          ...              ...              ...
# 8317           FDT57     0.633820                L         0.018943
# 8318           FDW02     0.014885                R         0.037517
# 8319           NCO02     0.392676                L         0.073013
# 8320           FDJ15     0.404585                R         0.023210
# 8321           FDL10     0.228639                L         0.039301
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                    Canned  0.259857            OUT010
# 1              Frozen Foods  0.298863            OUT010
# 2                    Others  0.428010            OUT010
# 3     Fruits and Vegetables  0.356086            OUT010
# 4                    Breads  0.701573            OUT010
# ...                     ...       ...               ...
# 8317            Snack Foods  0.868999            OUT027
# 8318                  Dairy  0.395081            OUT027
# 8319                 Others  0.153754            OUT027
# 8320                  Dairy  0.645466            OUT027
# 8321            Snack Foods  0.289536            OUT027
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                      0.541667       Small               Tier 3
# 1                      0.541667       Small               Tier 3
# 2                      0.541667       Small               Tier 3
# 3                      0.541667       Small               Tier 3
# 4                      0.541667       Small               Tier 3
# ...                         ...         ...                  ...
# 8317                   0.000000      Medium               Tier 3
# 8318                   0.000000      Medium               Tier 3
# 8319                   0.000000      Medium               Tier 3
# 8320                   0.000000      Medium               Tier 3
# 8321                   0.000000      Medium               Tier 3
#
#             Outlet_Type  Item_Outlet_Sales
# 0         Grocery Store           186.4240
# 1         Grocery Store           101.2016
# 2         Grocery Store           263.6568
# 3         Grocery Store           345.5502
# 4         Grocery Store           585.2382
# ...                 ...                ...
# 8317  Supermarket Type3          6636.6944
# 8318  Supermarket Type3          3004.0896
# 8319  Supermarket Type3          2306.9970
# 8320  Supermarket Type3          6064.1064
# 8321  Supermarket Type3          1884.8798
#
# [8322 rows x 12 columns]

# %%
Item_Fat_Content = pd.get_dummies(df['Item_Fat_Content']).drop('R', axis = 1)['L']
Item_Fat_Content
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 8317    1
# 8318    0
# 8319    1
# 8320    0
# 8321    1
# Name: L, Length: 8322, dtype: uint8

# %%
df['Item_Fat_Content'] = Item_Fat_Content

# %%
df
# Out:
#      Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0              FDB14     0.934504                 0         0.171939
# 1              FDS52     0.258113                 1         0.009163
# 2              NCN07     0.830307                 1         0.056816
# 3              FDI32     0.782673                 1         0.291865
# 4              FDR47     0.791605                 1         0.070088
# ...              ...          ...               ...              ...
# 8317           FDT57     0.633820                 1         0.018943
# 8318           FDW02     0.014885                 0         0.037517
# 8319           NCO02     0.392676                 1         0.073013
# 8320           FDJ15     0.404585                 0         0.023210
# 8321           FDL10     0.228639                 1         0.039301
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                    Canned  0.259857            OUT010
# 1              Frozen Foods  0.298863            OUT010
# 2                    Others  0.428010            OUT010
# 3     Fruits and Vegetables  0.356086            OUT010
# 4                    Breads  0.701573            OUT010
# ...                     ...       ...               ...
# 8317            Snack Foods  0.868999            OUT027
# 8318                  Dairy  0.395081            OUT027
# 8319                 Others  0.153754            OUT027
# 8320                  Dairy  0.645466            OUT027
# 8321            Snack Foods  0.289536            OUT027
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                      0.541667       Small               Tier 3
# 1                      0.541667       Small               Tier 3
# 2                      0.541667       Small               Tier 3
# 3                      0.541667       Small               Tier 3
# 4                      0.541667       Small               Tier 3
# ...                         ...         ...                  ...
# 8317                   0.000000      Medium               Tier 3
# 8318                   0.000000      Medium               Tier 3
# 8319                   0.000000      Medium               Tier 3
# 8320                   0.000000      Medium               Tier 3
# 8321                   0.000000      Medium               Tier 3
#
#             Outlet_Type  Item_Outlet_Sales
# 0         Grocery Store           186.4240
# 1         Grocery Store           101.2016
# 2         Grocery Store           263.6568
# 3         Grocery Store           345.5502
# 4         Grocery Store           585.2382
# ...                 ...                ...
# 8317  Supermarket Type3          6636.6944
# 8318  Supermarket Type3          3004.0896
# 8319  Supermarket Type3          2306.9970
# 8320  Supermarket Type3          6064.1064
# 8321  Supermarket Type3          1884.8798
#
# [8322 rows x 12 columns]

# %%
df['Outlet_Size'].value_counts()
# Out:
# Medium    2733
# Small     2334
# High       913
# Name: Outlet_Size, dtype: int64

# %%
df['Item_Type'].value_counts()
# Out:
# Fruits and Vegetables    1208
# Snack Foods              1161
# Household                 891
# Frozen Foods              836
# Dairy                     660
# Canned                    637
# Baking Goods              632
# Health and Hygiene        508
# Soft Drinks               439
# Meat                      414
# Breads                    246
# Hard Drinks               210
# Others                    168
# Starchy Foods             141
# Breakfast                 107
# Seafood                    64
# Name: Item_Type, dtype: int64

# %%
pd.get_dummies(df['Outlet_Size'])
# Out:
#       High  Medium  Small
# 0        0       0      1
# 1        0       0      1
# 2        0       0      1
# 3        0       0      1
# 4        0       0      1
# ...    ...     ...    ...
# 8317     0       1      0
# 8318     0       1      0
# 8319     0       1      0
# 8320     0       1      0
# 8321     0       1      0
#
# [8322 rows x 3 columns]
